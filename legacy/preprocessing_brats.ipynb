# %% [markdown]
# ###Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Upload Kaggle API Credentials
#
# This cell facilitates the secure upload of your `kaggle.json` file, which contains your Kaggle API authentication credentials. This step is crucial for programmatically interacting with Kaggle, such as downloading datasets, without manually logging in.
#
# (upload in side panel)

# %% [markdown]
# ### Configure Kaggle API Credentials
#
# After uploading `kaggle.json`, this cell moves the file to the correct directory (`~/.kaggle/`) and sets appropriate file permissions (`chmod 600`). This ensures that the Kaggle API client can find and securely use your credentials for subsequent operations like dataset downloads.

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# ### Download and Unzip Preprocessed Dataset from Kaggle
#
# This cell utilizes the Kaggle API to download the specified preprocessed brain MRI dataset directly into the `data/raw` directory of your project. The `--unzip` flag automatically extracts the contents, preparing the raw NIfTI files for further processing.

# %%
# !kaggle datasets download -d dschettler8845/brats-2021-task1 -p "/content/drive/MyDrive/symAD-ECNN/data/raw_brats"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dschettler8845/brats-2021-task1
# License(s): copyright-authors
# ^C

# %%
# !tar -xvf "/content/drive/MyDrive/symAD-ECNN/data/raw_brats/BraTS2021_Training_Data.tar" -C "/content/drive/MyDrive/symAD-ECNN/data/raw_brats"
# Out:
# unzip:  cannot find or open brats-2021-task1.zip, brats-2021-task1.zip.zip or brats-2021-task1.zip.ZIP.

# %%
import os
import zipfile

# Define paths (adjust if needed)
BASE = "/content/drive/MyDrive/symAD-ECNN"
zip_file = f"{BASE}/data/brats2021_processed_slices_20251229_140105.zip"  # Update with your zip filename
output_folder = f"{BASE}/data/brats2021_test"

# Create output folder
os.makedirs(output_folder, exist_ok=True)

# Extract zip file
print(f"Extracting {zip_file}...")
with zipfile.ZipFile(zip_file, 'r') as zip_ref:
    zip_ref.extractall(output_folder)

# Verify
import numpy as np
files = sorted([f for f in os.listdir(output_folder) if f.endswith('.npy')])
print(f"\n✅ Extraction complete!")
print(f"Total files: {len(files)}")

# Load and verify a sample
if files:
    sample = np.load(os.path.join(output_folder, files[0]))
    print(f"\nSample file: {files[0]}")
    print(f"Shape: {sample.shape}")
    print(f"Range: [{sample.min():.4f}, {sample.max():.4f}]")
# Out:
# Extracting /content/drive/MyDrive/symAD-ECNN/data/brats2021_processed_slices_20251229_140105.zip...
#
# ✅ Extraction complete!
# Total files: 49888
#
# Sample file: slice_000038.npy
# Shape: (128, 128)
# Range: [0.0000, 0.8583]
